# %% [markdown]
# # 第 8 次课：大模型与 AIGC
#
# ## 教学目标
#
# - 理解大模型的基本概念、能力边界与典型应用。
# - 认识提示词、RAG、智能体、多模态生成等实践方向。
# - 能完成一个面向教学或科研的 AIGC 小任务。
#
# ## 官方资料
#
# - `官方文档/08-大模型与AIGC/第5章 人工智能大模型.pptx`
#
# ## 代码实验
#
# 待补充。
#
# ## 课后任务
#
# 待补充。
