# %% [markdown]
# # 第 3 次课：人工神经网络基础
#
# ## 教学目标
#
# - 理解神经元、层、激活函数、前向传播与反向传播。
# - 能解释神经网络为什么能够拟合复杂函数。
# - 结合官方 PPT 梳理基础概念。
#
# ## 官方资料
#
# - `官方文档/03-人工神经网络基础/第四周人工神经网络基础.pptx`
#
# ## 代码实验
#
# 待补充。
#
# ## 课后任务
#
# 待补充。
