# %% [markdown]
# # 第 2 次课：机器学习基础
#
# ## 教学目标
#
# - 理解监督学习、无监督学习与强化学习的基本思路。
# - 掌握训练集、测试集、特征、标签、损失函数等核心概念。
# - 能运行一个基础机器学习分类实验。
#
# ## 课堂主线
#
# 1. 从规则编程到数据驱动
# 2. 机器学习基本流程
# 3. 常见模型与评价指标
# 4. 简单分类实验
#
# ## 代码实验
#
# 待补充。
#
# ## 课后任务
#
# 待补充。
