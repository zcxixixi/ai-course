# %% [markdown]
# # 第 6 次课：计算机视觉
#
# ## 教学目标
#
# - 理解图像数据、卷积神经网络和视觉分类任务。
# - 能运行 MNIST 手写数字识别实验。
# - 通过案例连接模型结构、训练过程与评价结果。
#
# ## 官方资料
#
# - `官方文档/06-计算机视觉-手写数字识别/实践1-手写数字识别.pptx`
# - `官方文档/06-计算机视觉-手写数字识别/项目1-卷积神经网络（CNN）实现MNIST手写数字识别.docx`
#
# ## 代码实验
#
# 待补充。
#
# ## 课后任务
#
# 待补充。
