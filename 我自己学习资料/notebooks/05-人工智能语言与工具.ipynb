# %% [markdown]
# # 第 5 次课：人工智能语言与工具
#
# ## 教学目标
#
# - 熟悉 Python、Jupyter、常用 AI 框架与开发工具链。
# - 理解环境配置、包管理、Notebook 实验记录的基本方法。
# - 能独立运行一个最小 AI 实验。
#
# ## 官方资料
#
# - `官方文档/00-环境配置/环境配置.pdf`
#
# ## 代码实验
#
# 待补充。
#
# ## 课后任务
#
# 待补充。
