# %% [markdown]
# # 第 7 次课：自然语言处理
#
# ## 教学目标
#
# - 理解文本表示、分词、词向量、序列建模等基础概念。
# - 认识 Transformer 与大语言模型的技术衔接。
# - 能完成一个简单文本处理或分类实验。
#
# ## 课堂主线
#
# 1. 文本数据的特点
# 2. 从词袋模型到词向量
# 3. 序列模型与注意力机制
# 4. NLP 实验案例
#
# ## 代码实验
#
# 待补充。
#
# ## 课后任务
#
# 待补充。
